# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("Dont use this/bank_data.csv", index_col=0)
data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
X = data.drop(["y"], axis=1)
y = data["y"]

# %%
X
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
y
# Out:
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
#         ..
# 4516    no
# 4517    no
# 4518    no
# 4519    no
# 4520    no
# Name: y, Length: 4521, dtype: object

# %%
y.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
X_train, X_val, y_train, y_val = train_test_split(
        X, y, stratify=y, test_size=0.3, random_state = 42)
y_train.map({"yes": 1, "no": 0}).hist()
# Out:
# <Axes: >

# %%
y_val.map({"yes": 1, "no": 0}).hist()
# Out:
# <Axes: >

# %%
data_train = X_train
data_train["y"] = y_train
data_train.reset_index(drop = True, inplace = True)
data_train
# Out:
#       age           job   marital  education default  balance housing loan  \
# 0      37  entrepreneur    single   tertiary      no     1467     yes  yes
# 1      25    unemployed    single  secondary      no       34      no  yes
# 2      53       retired   married  secondary      no     1278     yes   no
# 3      31     housemaid   married    unknown     yes       -6      no  yes
# 4      43    unemployed   married  secondary      no     3529      no   no
# ...   ...           ...       ...        ...     ...      ...     ...  ...
# 3159   55      services  divorced    primary      no      653      no   no
# 3160   39   blue-collar   married    unknown      no        0      no   no
# 3161   35    technician   married  secondary      no        0      no   no
# 3162   37      services    single  secondary      no      105      no  yes
# 3163   63       retired   married  secondary      no      474      no   no
#
# ...

# %%
data_val = X_val
data_val["y"] = y_val
data_val.reset_index(drop = True, inplace = True)
data_val
# Out:
#       age           job   marital  education default  balance housing loan  \
# 0      44  entrepreneur    single   tertiary      no     1136     yes  yes
# 1      34    management   married   tertiary      no      180      no   no
# 2      32    management    single   tertiary      no      474     yes   no
# 3      30    technician    single   tertiary      no     6619     yes   no
# 4      46    management   married   tertiary      no     1375     yes   no
# ...   ...           ...       ...        ...     ...      ...     ...  ...
# 1352   40        admin.   married  secondary      no      168     yes   no
# 1353   34        admin.    single   tertiary      no       18     yes  yes
# 1354   33      services  divorced  secondary      no      411     yes   no
# 1355   46        admin.   married  secondary      no      120     yes   no
# 1356   36    management    single   tertiary      no      553      no   no
#
# ...

# %%
data_train.to_csv("bank_train_data.csv")
data_val.to_csv("bank_val_data.csv")

# %%
import os
os.system('jupyter nbconvert --to html train_val_split_script.ipynb')
# Out:
# 0
